# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.381200  0.157185 -0.582365  0.087745
# 1   -0.538709  0.722249 -1.495203 -1.289935
# 2    1.559962  1.483081  1.189187  2.241781
# 3   -0.541001 -0.753725  0.127428  0.013555
# 4    1.335596  2.343057  0.662054 -0.062476
# ..        ...       ...       ...       ...
# 495 -0.272344  1.144394  1.739053  0.162932
# 496  1.172833  0.835079 -1.913623  0.035854
# 497  0.571296 -1.911987  0.392552 -0.021515
# 498  0.055370  0.416552 -1.368693 -0.351114
# 499 -0.110423  0.810937  0.729526 -0.497919
#
# [500 rows x 4 columns]

# %%
# Density and kernel density estimation plots with scipy
my_df.plot(kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# KDE second way to learn shift tab
my_df.plot.kde(alpha=0.4, lw=4)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Density Plot
my_df.plot(kind='density')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Other method
my_df.plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Title
my_df.plot.density(title="My Awesome Density Plot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Density Plot'}, ylabel='Density'>

# %%
# Grid
my_df.plot.density(grid=True)
# Out:
# <AxesSubplot: ylabel='Density'>
