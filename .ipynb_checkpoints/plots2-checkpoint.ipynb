# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.713153  0.364649 -0.351189  2.011458
# 1   -0.729153 -0.821706 -0.480502 -0.419556
# 2   -1.608545 -0.663377 -1.665173  1.753856
# 3   -0.634055  0.197370 -0.729206  2.826746
# 4   -0.632713  0.329780  1.259690 -0.542457
# ..        ...       ...       ...       ...
# 495  1.487695 -0.081469  0.586694 -1.874907
# 496 -3.202802 -0.168385 -0.167771  0.709595
# 497 -0.143152 -0.865616  1.393277  0.739833
# 498  0.851047  1.401198  0.903600 -0.500411
# 499  1.511021  0.144843 -1.560143  0.539788
#
# [500 rows x 4 columns]

# %%
# Boxplots
my_df.plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
# Boxplots Size
my_df.plot(kind='box', figsize=(10,5))
# Out:
# <AxesSubplot: >

# %%
# Boxplots Color
my_df.plot(kind='box', figsize=(10,5), cmap="jet")
# Out:
# <AxesSubplot: >

# %%
# No Legend
my_df.plot(kind='box', figsize=(10,5), legend=True)
# Out:
# <AxesSubplot: >

# %%
# Title
my_df.plot(kind='box', figsize=(10,5), title='My Awesome Box Plot', cmap='winter')
# Out:
# <AxesSubplot: title={'center': 'My Awesome Box Plot'}>

# %%
# Other Way
my_df.plot.box(figsize=(10,5), title='My Awesome Box Plot', cmap='winter')
# Out:
# <AxesSubplot: title={'center': 'My Awesome Box Plot'}>

# %%
# Add Grid
my_df.plot.box(figsize=(10,5), title='My Awesome Box Plot', cmap='winter', grid=True)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Box Plot'}>
