# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.025964  0.376354 -1.281540  0.267212
# 1    0.971988 -1.187496  0.405076  1.283395
# 2   -0.106829  0.713663 -1.183529  1.166094
# 3    0.000274  0.236330 -0.732502  1.742400
# 4   -0.567650  0.393873 -0.583548  1.031285
# ..        ...       ...       ...       ...
# 495 -0.017600 -0.200189  1.376016 -0.563275
# 496 -0.485508  1.441269 -0.618731  0.351341
# 497  1.278592  1.149846 -0.778572  0.024037
# 498 -0.056881  0.444152 -1.431272  0.909286
# 499  1.646197 -2.111039 -1.512780 -0.496935
#
# [500 rows x 4 columns]

# %%
# Hexplots
my_df.plot(kind='hexbin', x='Mon', y='Tues')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots gridsize
my_df.plot(kind='hexbin', x='Mon', y='Tues', gridsize=10) # next try 25
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots color
my_df.plot(kind='hexbin', x='Mon', y='Tues', gridsize=25, cmap='magma')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Other method
my_df.plot.hexbin(x='Mon', y='Tues', gridsize=25)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot.hexbin(x='Mon', y='Tues', gridsize=25, title="My Awesome Hexbin Plot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Hexbin Plot'}, xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot.hexbin(x='Mon', y='Tues', gridsize=25, grid=True)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>
