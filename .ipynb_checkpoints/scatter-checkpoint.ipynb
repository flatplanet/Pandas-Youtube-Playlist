# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    2.258331  0.589521 -1.852548  0.195756
# 1   -0.368064  0.232692 -0.067016  1.039315
# 2   -0.165970  0.305071  1.561379  1.174879
# 3    1.020609  0.126420  1.626394  0.238977
# 4   -0.048636  0.210159 -0.014306 -1.430202
# ..        ...       ...       ...       ...
# 495  0.301503 -1.449719  0.608975 -1.011003
# 496  1.064059 -0.128423 -0.258790  0.295505
# 497 -1.323495 -0.510460  1.028206  0.179066
# 498 -0.365640 -0.201575 -1.218470 -0.457466
# 499 -0.677079  0.719425 -0.592540  1.814846
#
# [500 rows x 4 columns]

# %%
# Scatter plot
my_df.plot(kind='scatter', x='Mon', y='Tues', c="Wed", cmap='magma') # matplotlib colormaps
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
my_df.plot(kind='scatter', x='Mon', y='Tues', c="Wed", cmap='PuBu')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed'])
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*50)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*100, alpha=0.4)
# Out:
# C:\code\mydata\virt\Lib\site-packages\matplotlib\collections.py:967: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# line Width
my_df[['Mon', 'Tues']].abs().plot(kind='line', figsize=(10,5), lw=3)
# Out:
# <AxesSubplot: >

# %%
# Title
my_df[['Mon', 'Tues']].abs().plot(kind='line', figsize=(10,5), title="My Awesome Line Graph")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Line Graph'}>

# %%
# Shading 
my_df[['Mon', 'Tues']].abs().plot(kind='line', figsize=(10,5), title="My Awesome Line Graph", alpha=0.3)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Line Graph'}>

# %%
# legend
my_df[['Mon', 'Tues']].abs().plot(kind='line', figsize=(10,5), title="My Awesome Line Graph", legend=False)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Line Graph'}>

# %%
# Second Way chart
my_df.plot.line()
# Out:
# <AxesSubplot: >
