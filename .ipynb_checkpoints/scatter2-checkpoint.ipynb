# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.420092  1.750007  0.720696 -0.639747
# 1    0.044096 -0.292885 -0.194430 -0.048013
# 2   -0.165380 -0.656083  1.674056  0.272488
# 3   -0.384493 -0.080070  1.111136 -0.837431
# 4    1.558305 -1.797761  0.411965 -1.408038
# ..        ...       ...       ...       ...
# 495  0.232892  0.155585  1.058490  0.798008
# 496  0.321133 -1.970585  0.397641  1.465239
# 497 -1.353065  1.488581 -1.141406  1.320868
# 498  0.378431 -0.819122  0.319992  0.862732
# 499 -0.876099  0.193341 -0.594975  1.498238
#
# [500 rows x 4 columns]

# %%
# Scatter plot
my_df.plot(kind='scatter', x="Mon", y="Tues", c="Wed")
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Colors: https://matplotlib.org/stable/tutorials/colors/colormaps.html
my_df.plot(kind='scatter', x="Mon", y="Tues", c="Wed", cmap='magma')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind='scatter', x="Mon", y="Tues", s=my_df['Wed']*100, cmap='copper')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha
my_df.plot(kind='scatter', x="Mon", y="Tues", s=my_df['Wed']*100, alpha=0.4)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Title Etc
my_df.plot(kind='scatter', x="Mon", y="Tues", s=my_df['Wed']*100, alpha=0.4, title="My Awesome Scatterplot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Scatterplot'}, xlabel='Mon', ylabel='Tues'>
