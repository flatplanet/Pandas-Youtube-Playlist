# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.600873 -1.312856 -0.408199 -1.813455
# 1    1.412479 -1.474054 -0.958677  1.212600
# 2    0.340393 -0.502397 -2.139734 -0.795571
# 3   -0.488078  0.492332 -0.408518  0.156502
# 4    0.955874  0.317665  0.380635  0.419496
# ..        ...       ...       ...       ...
# 495  0.276898  0.445350  0.840654  0.549950
# 496 -1.825857  0.036744 -0.142604 -0.619779
# 497 -0.139603 -0.779814 -0.289554 -1.131474
# 498 -0.120344  1.661907  0.588383  0.688170
# 499  0.600797  1.096754 -1.269013 -0.165466
#
# [500 rows x 4 columns]

# %%
# Scatter plot
my_df.plot(kind='scatter', x="Mon", y="Tues", c="Wed", cmap='prism')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Colors: https://matplotlib.org/stable/tutorials/colors/colormaps.html
my_df.plot(kind='scatter', x="Mon", y="Tues", c="Wed", cmap='copper')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind='scatter', x="Mon", y="Tues", s=my_df['Wed']*100, cmap='copper')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha
my_df.plot(kind='scatter', x="Mon", y="Tues", s=my_df['Wed']*100, alpha=0.4)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Title Etc
my_df.plot(kind='scatter', x="Mon", y="Tues", s=my_df['Wed']*100, alpha=0.4, title="My Awesome Scatterplot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Scatterplot'}, xlabel='Mon', ylabel='Tues'>
