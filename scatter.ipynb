# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.629608  1.272862 -0.388394  1.813119
# 1    1.629899  2.204869  1.640913  0.301681
# 2    0.132523 -0.543933  1.129228  0.170352
# 3    0.435110 -0.134647  0.215140  0.704922
# 4    0.632364 -0.204414  0.949836  1.641916
# ..        ...       ...       ...       ...
# 495  0.314145 -1.072088  0.744468 -0.037227
# 496 -1.012132 -0.664095  0.642785 -0.206042
# 497 -0.582108  1.075088  1.241066  1.365228
# 498  0.484395 -1.587227 -0.063145  0.504607
# 499  0.853339  1.549339  0.101128  0.324300
#
# [500 rows x 4 columns]

# %%
# Scatter plot
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed")
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Colors: https://matplotlib.org/stable/tutorials/colors/colormaps.html
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed", cmap='magma')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df['Wed']*100)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df['Wed']*200, alpha=0.4)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Title Etc
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df['Wed']*200, alpha=0.4, title="My Awesome ScatterPlot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome ScatterPlot'}, xlabel='Mon', ylabel='Tues'>
