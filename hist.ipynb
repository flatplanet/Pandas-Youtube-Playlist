# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create a quick dataframe
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   1.574934 -0.363128 -0.935420  1.177255
# 1  -0.791473 -0.819431  0.139974 -1.064381
# 2  -1.425311  0.885635 -1.206950  0.326504
# 3  -0.061413  1.383721  0.656111  0.258302
# 4  -1.068156 -0.026076  0.959083  0.288142
# ..       ...       ...       ...       ...
# 95 -0.496571  0.313064  0.022386 -0.118773
# 96 -0.650570  0.959926 -0.888278  1.216547
# 97  0.531272 -2.907022 -1.024808 -0.082759
# 98 -2.438756  0.515625  1.590891  0.666800
# 99 -0.203590 -0.448533  1.206726  1.231468
#
# [100 rows x 4 columns]

# %%
# Histogram
my_df["Wed"].hist()
# Out:
# <AxesSubplot: >

# %%
# Histogram with Smaller bins, 50, 20
my_df["Wed"].hist(bins=20)
# Out:
# <AxesSubplot: >

# %%
# Another way without grid bars
my_df["Wed"].plot(kind="hist", bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
my_df["Wed"].hist(bins=20, grid=False, legend=True)
# Out:
# <AxesSubplot: >
