# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.940100 -0.786734 -0.246712  1.335472
# 1   -0.754008  0.246577  0.062576 -0.307082
# 2    0.379504  0.036042 -0.433460 -0.776763
# 3   -0.540497  0.157027  1.547871  0.076585
# 4    2.614400  1.261519 -0.358480 -1.118019
# ..        ...       ...       ...       ...
# 495 -2.195383 -0.618083  1.805426 -0.564382
# 496 -0.513341  1.110084 -2.278812  0.089284
# 497 -1.148378  0.113473 -1.100268  0.312244
# 498  0.377103  0.898351  0.650142  1.397853
# 499 -0.980357  2.125145 -0.514017 -0.227463
#
# [500 rows x 4 columns]

# %%
# Hexplots
my_df.plot(kind="hexbin", x="Mon", y="Tues")
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots gridsize
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots color
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, cmap="Wistia")
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Other method
my_df.plot.hexbin(x="Mon", y="Tues", C="Wed", gridsize=10)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot.hexbin(x="Mon", y="Tues", C="Wed", gridsize=10, title="My Awesome Hex Plot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Hex Plot'}, xlabel='Mon', ylabel='Tues'>

# %%
# Grid
my_df.plot.hexbin(x="Mon", y="Tues", C="Wed", gridsize=10, title="My Awesome Hex Plot", grid=True)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Hex Plot'}, xlabel='Mon', ylabel='Tues'>
