# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(25,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#          Mon      Tues       Wed     Thurs
# 0  -0.769935  0.827044 -0.330448  0.533547
# 1  -0.675915  0.211280 -0.389126  0.181590
# 2  -0.415183 -0.718942 -0.031270  0.582308
# 3  -0.097255 -1.468577 -0.116836  1.399780
# 4   1.188930 -0.157711  0.309556  0.157755
# 5  -1.569992  0.960539  0.713520  0.720008
# 6   2.228887  1.015837 -0.104109 -0.216145
# 7   1.099549  1.012260 -0.246141  0.287675
# 8  -0.250469  1.080923 -0.618932  1.976525
# 9  -0.385834 -1.808925 -0.176004 -0.209364
# 10  0.114294 -0.805842  1.778749  1.797930
# 11  0.781736 -0.681994 -2.006983 -0.556587
# 12  0.662998  0.005871  0.962835 -0.450128
# 13 -0.779183 -0.001639  0.194727  0.453409
# 14  1.101755 -0.864435  2.108280  0.543722
# 15 -0.876040 -2.118157 -0.702153 -0.300094
# 16  1.785863  0.570401  1.210653  0.153794
# 17  0.648513 -0.582246 -1.198289  0.690510
# 18  0.409530  0.493115  0.377002 -0.909094
# 19  1.179319 -0.201636 -0.753624 -0.058586
# 20  1.974058  1.351875 -0.495600  0.414544
# 21 -0.838792 -0.132752 -0.307267  0.349325
# 22  1.746937 -0.796000  3.105639 -1.811279
# 23  1.869272  1.554879  0.185515 -0.402419
# 24  0.050942 -0.060247  0.609249 -0.740601

# %%
# bar plot
my_df.abs().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# bar plot Stacked
my_df.abs().plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot: >

# %%
# Shading 
my_df.abs().plot(kind="bar", stacked=True, alpha=0.4)
# Out:
# <AxesSubplot: >

# %%
# Title
my_df.abs().plot(kind="bar", stacked=True, title="My Awesome Bar Chart")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Bar Chart'}>

# %%
# legend
my_df.abs().plot(kind="bar", stacked=True, title="My Awesome Bar Chart", legend=False)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Bar Chart'}>

# %%
# Second Way
my_df.abs().plot.bar()
# Out:
# <AxesSubplot: >

# %%
# Second Way Stacked
my_df.abs().plot.bar(stacked=True)
# Out:
# <AxesSubplot: >

# %%
# Second Way Shading 
my_df.abs().plot.bar(stacked=True, alpha=0.4)
# Out:
# <AxesSubplot: >

# %%
# Second Way Title
my_df.abs().plot.bar(stacked=True, title="My Bodacious Bar Chart?!")
# Out:
# <AxesSubplot: title={'center': 'My Bodacious Bar Chart?!'}>

# %%
# Second Way Legend
my_df.abs().plot.bar(stacked=True, legend=False)
# Out:
# <AxesSubplot: >

# %%
# Grid Lines
my_df.abs().plot.bar(stacked=True, grid=True)
# Out:
# <AxesSubplot: >
