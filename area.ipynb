# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(25,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#          Mon      Tues       Wed     Thurs
# 0  -0.930394  0.474871 -0.118732  0.222288
# 1   0.856026  1.041216 -0.272603 -1.705847
# 2  -0.781603  0.687002  1.456072 -0.681924
# 3  -0.085117  0.581137  2.263281 -0.412787
# 4  -1.020194 -1.171906 -0.501189 -0.436582
# 5  -2.299378 -0.735170 -0.429247  0.088315
# 6   2.453355  0.103326 -1.387793  1.691855
# 7  -0.209587  0.366649  0.171272  0.275981
# 8  -1.138965  0.229170  0.519003  1.416266
# 9  -0.042359 -0.692376 -0.452876 -1.274663
# 10  1.346639  0.389344  0.895351  1.053100
# 11 -0.127334  0.035002  0.413944 -1.368304
# 12  1.077653 -0.078889 -0.154821  1.553565
# 13 -1.422362  0.241399  2.091821 -0.539196
# 14  0.675691 -0.414521 -1.692915 -1.950738
# 15  0.073572  2.350751 -0.539394  0.900878
# 16 -0.108212  0.691549 -0.922126  1.219408
# 17 -0.337820  0.694429 -1.672743  1.936174
# 18  0.033963 -1.510431 -0.049148  0.680929
# 19 -0.199675  1.180628  0.880341  0.205508
# 20 -1.962554 -1.264768 -0.042701 -0.273962
# 21  1.097157 -0.113746 -1.267639 -0.460559
# 22 -0.374198  0.617847  0.191787 -0.832018
# 23 -0.770843 -0.215374  1.538776 -0.647570
# 24 -2.125472  0.347357 -0.107729 -1.915455

# %%
# area plot
my_df.abs().plot(kind='area')
# Out:
# <AxesSubplot: >

# %%
# Shading
my_df.abs().plot(kind='area', alpha=0.5)
# Out:
# <AxesSubplot: >

# %%
# Title
my_df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot!'}>

# %%
# legend
my_df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot!'}>

# %%
# Plot only one column
my_df['Mon'].abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot!'}>

# %%
# Plot 2 columns
my_df[['Mon', "Thurs"]].abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot!'}>

# %%
# Get info on function
my_df[['Mon', "Thurs"]].plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False)

# %%
# Add Table
my_df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False, table=True)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot!'}>
