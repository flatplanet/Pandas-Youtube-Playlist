# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.638759 -0.690046  0.291993 -2.277619
# 1   -0.528686 -0.477085  1.581360 -0.947648
# 2    0.412811 -0.411803 -0.447247 -0.414610
# 3   -0.611344 -0.037208 -0.121464  1.277822
# 4   -0.496880  0.245025 -0.114857  0.299835
# ..        ...       ...       ...       ...
# 495 -1.659335 -0.731873  0.844541 -0.198678
# 496 -0.928431 -1.809690 -0.156147 -0.480779
# 497  0.940816 -1.549800 -0.191048  0.681461
# 498  0.547209  1.019817 -1.301380 -2.227505
# 499 -0.896243  1.058418 -0.138406 -0.651544
#
# [500 rows x 4 columns]

# %%
# Density and kernel density estimation plots with scipy
my_df.plot(kind="kde")
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# KDE second way to learn shift tab
my_df.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Density Plot
my_df.plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Other method
my_df.plot(kind="density")
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Change stuff
my_df["Tues"].plot.kde(alpha=0.4, lw=4)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Grid
my_df["Tues"].plot.kde(alpha=0.4, lw=4, grid=True)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Title
my_df["Tues"].plot.kde(alpha=0.4, lw=4, title="My Awesome KDE Plot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome KDE Plot'}, ylabel='Density'>
