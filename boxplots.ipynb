# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.057902 -0.929334  0.705436  0.812460
# 1    1.208572  0.604252 -0.924487  1.947917
# 2    0.776598  0.580948  0.708367 -0.349370
# 3    0.738453 -0.940894  0.487311 -0.577172
# 4   -0.162274 -0.058603  1.119123  0.544227
# ..        ...       ...       ...       ...
# 495 -0.736502  1.709797 -0.037710  0.136023
# 496  0.786930  1.730983 -0.091414  1.633700
# 497 -2.886809  0.037868 -0.376976  1.416435
# 498 -0.166905 -0.102397  0.080873  0.912859
# 499 -0.232193 -0.207309  0.581143  2.069962
#
# [500 rows x 4 columns]

# %%
# Boxplots
my_df.plot(kind="box")
# Out:
# <AxesSubplot: >

# %%
# Boxplots Size
my_df.plot(kind="box", figsize=(10, 5))
# Out:
# <AxesSubplot: >

# %%
# Boxplots Color
my_df.plot(kind="box", cmap="jet")
# Out:
# <AxesSubplot: >

# %%
# No Legend
my_df.plot(kind="box", lengend=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # No Legend
# ----> 2 my_df.plot(kind="box", lengend=True)
#
# File c:\mydata\virt\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\mydata\virt\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\mydata\virt\lib\site-packages\pandas\plotting\_matplotlib\core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File c:\mydata\virt\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:181, in BoxPlot._make_plot(self)
#     178 ax = self._get_ax(0)
#     179 kwds = self.kwds.copy()
# --> 181 ret, bp = self._plot(
#     182     ax, y, column_num=0, return_type=self.return_type, **kwds
#     183 )
#     184 self.maybe_color_bp(bp)
#     185 self._return_obj = ret
#
# File c:\mydata\virt\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:74, in BoxPlot._plot(cls, ax, y, column_num, return_type, **kwds)
#      72 else:
#      73     y = remove_na_arraylike(y)
# ---> 74 bp = ax.boxplot(y, **kwds)
#      76 if return_type == "dict":
#      77     return bp, bp
#
# File c:\mydata\virt\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# TypeError: boxplot() got an unexpected keyword argument 'lengend'

# %%
# Title
my_df.plot(kind="box", title="My Awesome Box Plot!")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Box Plot!'}>

# %%
# Other Way
my_df.plot.box(title="My Awesome Box Plot!!!!!!!!")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Box Plot!!!!!!!!'}>

# %%
# Add Grid
my_df.plot.box(title="My Awesome Box Plot!!!!!!!!", grid=True)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Box Plot!!!!!!!!'}>

# %%
my_df.plot.box(title="My Awesome Box Plot!!!!!!!!")
